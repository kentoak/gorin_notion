# %%
import requests
from pprint import pprint
import json

def get_request_url(end_point):
    return f'https://api.notion.com/v1/{end_point}'
notion_api_key = 'secret_3Cb6K5W7LhSnV8PWcnoMn2z2hn8HWgEB7QRc2kzBuTi'
headers_for_notion = {"Authorization": f"Bearer {notion_api_key}",
           "Content-Type": "application/json",
           "Notion-Version": "2022-06-28"}
databases_ids=[
    'https://www.notion.so/ac0ed11843404278a9fd1aa0f99b0336?v=985b1637dc6c40eeb8c3bb1db2f9182c'
]
databases_id=databases_ids[0][22:][:databases_ids[0][22:].find('?')]
print(databases_id)
response = requests.request('GET', url=get_request_url(f'databases/{databases_id}'), headers=headers_for_notion)
print(response)
# Out:
# ac0ed11843404278a9fd1aa0f99b0336
# <Response [200]>

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

for year in range(2008,2023):
    for gender_code in range(2,0,-1):
        for waterway_code in range(1,2):
            for swimming_style_code in range(5,0,-1):
                if swimming_style_code==5:
                    for distance_code in range(5,3,-1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                                with open(filename,"w") as fp:
                                    json.dump(body,fp)
                elif swimming_style_code==1:
                    for distance_code in range(7,1,-1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                                with open(filename,"w") as fp:
                                    json.dump(body,fp)
                else:
                    for distance_code in range(4,1,-1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                                with open(filename,"w") as fp:
                                    json.dump(body,fp)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-49b0e8d2450a> in <module>
#      39                             url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
#      40                             request= Request(url, headers=headers)
# ---> 41                             with urlopen(request) as response:
#      42                                 body=json.loads(response.read())
#      43                                 with open(filename,"w") as fp:
#
# ...

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2009
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2010
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2011
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2012
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2013
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2014
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2015
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2016
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2017
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2018
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2019
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2020
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2021
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2022
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64
import json

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)

with urlopen(request) as response:
    a=response.read()
    allpage=json.loads(a)["meta"]["last_page"]
allpage=4

year=2008
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:
                for distance_code in range(5,3,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            elif swimming_style_code==1:
                for distance_code in range(7,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)
            else:
                for distance_code in range(4,1,-1):
                    for p in range(1,allpage+1):
                        title=str(year)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                        filename="/Users/kt/swim/ja_rankings/"+title+".json"
                        url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                        request= Request(url, headers=headers)
                        with urlopen(request) as response:
                            body=json.loads(response.read())
                            with open(filename,"w") as fp:
                                json.dump(body,fp)

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)
with urlopen(request) as response:
    allpage=json.loads(response.read())["meta"]["last_page"]
allpage=1

for year in range(2008,2023):
    for gender_code in range(2,0,-1):
        for waterway_code in range(1,2):
            for swimming_style_code in range(5,0,-1):
                if swimming_style_code==5:
                    for distance_code in range(5,3,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                elif swimming_style_code==1:
                    for distance_code in range(7,1,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                else:
                    for distance_code in range(4,1,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")

for year in range(2008,2023):
    for gender_code in range(2,0,-1):
        for waterway_code in range(1,2):
            for swimming_style_code in range(5,0,-1):
                if swimming_style_code==5:
                    for distance_code in range(5,3,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                            #{'ranking': 1, 'ranking_in_overall': 1, 'record': {'id': 19889392, 'is_relay_first': False, 'record': '1:55.04', 'achieve_date': '2018年02月17日(土)', 'is_new': False}, 'swimmers': {'swimmer_name': '池江璃花子', 'swimmer_code': '3479935', 'entry_group': {'code': '13560', 'name': 'ﾙﾈｻﾝｽ亀戸', 'short_name': 'ﾙﾈｻﾝｽ亀戸', 'member_group': {'code': 13, 'name': '東京'}}, 'school_class': {'code': 3, 'name': '高校', 'school_grades': [2]}}, 'achieved_game': {'game_name': '東京：KONAMI OPEN 2018', 'game_code': '1317644', 'division': {'code': 4, 'name': '決勝(A-決勝)'}, 'swimming_style_code': 1, 'distance_code': 4, 'gender_code': 2, 'race_division_code': 4, 'class_code': 4, 'heat': 1}, 'updated_at': '2021/04/03/00:33'}
                            for i in range(len(body["data"])-1,-1,-1):
                                body_for_notion = {
                                        "parent": {
                                            "database_id": databases_id
                                        },
                                        "properties": {
                                                "Rank": {"title": [{"text": {"content": str(body["data"][i]["ranking"])}}]},
                                                "Name": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["swimmer_name"]}}]},
                                                "EntryGroup": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["entry_group"]["name"]}}]},
                                                "Time": {"rich_text": [{"text": {"content": body["data"][i]["record"]["record"]}}]},
                                                "Game": {"rich_text": [{"text": {"content": body["data"][i]["achieved_game"]["game_name"]}}]},
                                                "Date": {"rich_text": [{"text": {"content": body["data"][i]["record"]["achieve_date"]}}]},
                                        }
                                }
                                res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                                print(body["data"][i]["ranking"],body["data"][i]["swimmers"]["swimmer_name"],body["data"][i]["swimmers"]["entry_group"]["name"],body["data"][i]["record"]["record"],body["data"][i]["achieved_game"]["game_name"],body["data"][i]["record"]["achieve_date"])
                        title="<"+str(year)+" "+str(gender_code_dict[gender_code])+" "+str(waterway_code_dict[waterway_code])+" "+str(distance_code_dict[distance_code])+" "+str(swimming_style_code_dict[swimming_style_code])+">"
                        body_for_notion = {
                            "parent": {
                                "database_id": databases_id
                            },
                            "properties": {
                                "Rank": {"title": [{"text": {"content": title}}]}
                            }
                        }
                        res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                        print("\n")
                elif swimming_style_code==1:
                    for distance_code in range(7,1,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                            #{'ranking': 1, 'ranking_in_overall': 1, 'record': {'id': 19889392, 'is_relay_first': False, 'record': '1:55.04', 'achieve_date': '2018年02月17日(土)', 'is_new': False}, 'swimmers': {'swimmer_name': '池江璃花子', 'swimmer_code': '3479935', 'entry_group': {'code': '13560', 'name': 'ﾙﾈｻﾝｽ亀戸', 'short_name': 'ﾙﾈｻﾝｽ亀戸', 'member_group': {'code': 13, 'name': '東京'}}, 'school_class': {'code': 3, 'name': '高校', 'school_grades': [2]}}, 'achieved_game': {'game_name': '東京：KONAMI OPEN 2018', 'game_code': '1317644', 'division': {'code': 4, 'name': '決勝(A-決勝)'}, 'swimming_style_code': 1, 'distance_code': 4, 'gender_code': 2, 'race_division_code': 4, 'class_code': 4, 'heat': 1}, 'updated_at': '2021/04/03/00:33'}
                            for i in range(len(body["data"])-1,-1,-1):
                                body_for_notion = {
                                        "parent": {
                                            "database_id": databases_id
                                        },
                                        "properties": {
                                                "Rank": {"title": [{"text": {"content": str(body["data"][i]["ranking"])}}]},
                                                "Name": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["swimmer_name"]}}]},
                                                "EntryGroup": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["entry_group"]["name"]}}]},
                                                "Time": {"rich_text": [{"text": {"content": body["data"][i]["record"]["record"]}}]},
                                                "Game": {"rich_text": [{"text": {"content": body["data"][i]["achieved_game"]["game_name"]}}]},
                                                "Date": {"rich_text": [{"text": {"content": body["data"][i]["record"]["achieve_date"]}}]},
                                        }
                                }
                                res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                                print(body["data"][i]["ranking"],body["data"][i]["swimmers"]["swimmer_name"],body["data"][i]["swimmers"]["entry_group"]["name"],body["data"][i]["record"]["record"],body["data"][i]["achieved_game"]["game_name"],body["data"][i]["record"]["achieve_date"])
                        title="<"+str(year)+" "+str(gender_code_dict[gender_code])+" "+str(waterway_code_dict[waterway_code])+" "+str(distance_code_dict[distance_code])+" "+str(swimming_style_code_dict[swimming_style_code])+">"
                        body_for_notion = {
                            "parent": {
                                "database_id": databases_id
                            },
                            "properties": {
                                "Rank": {"title": [{"text": {"content": title}}]}
                            }
                        }
                        res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                        print("\n")
                else:
                    for distance_code in range(4,1,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                            #{'ranking': 1, 'ranking_in_overall': 1, 'record': {'id': 19889392, 'is_relay_first': False, 'record': '1:55.04', 'achieve_date': '2018年02月17日(土)', 'is_new': False}, 'swimmers': {'swimmer_name': '池江璃花子', 'swimmer_code': '3479935', 'entry_group': {'code': '13560', 'name': 'ﾙﾈｻﾝｽ亀戸', 'short_name': 'ﾙﾈｻﾝｽ亀戸', 'member_group': {'code': 13, 'name': '東京'}}, 'school_class': {'code': 3, 'name': '高校', 'school_grades': [2]}}, 'achieved_game': {'game_name': '東京：KONAMI OPEN 2018', 'game_code': '1317644', 'division': {'code': 4, 'name': '決勝(A-決勝)'}, 'swimming_style_code': 1, 'distance_code': 4, 'gender_code': 2, 'race_division_code': 4, 'class_code': 4, 'heat': 1}, 'updated_at': '2021/04/03/00:33'}
                            for i in range(len(body["data"])-1,-1,-1):
                                body_for_notion = {
                                        "parent": {
                                            "database_id": databases_id
                                        },
                                        "properties": {
                                                "Rank": {"title": [{"text": {"content": str(body["data"][i]["ranking"])}}]},
                                                "Name": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["swimmer_name"]}}]},
                                                "EntryGroup": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["entry_group"]["name"]}}]},
                                                "Time": {"rich_text": [{"text": {"content": body["data"][i]["record"]["record"]}}]},
                                                "Game": {"rich_text": [{"text": {"content": body["data"][i]["achieved_game"]["game_name"]}}]},
                                                "Date": {"rich_text": [{"text": {"content": body["data"][i]["record"]["achieve_date"]}}]},
                                        }
                                }
                                res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                                print(body["data"][i]["ranking"],body["data"][i]["swimmers"]["swimmer_name"],body["data"][i]["swimmers"]["entry_group"]["name"],body["data"][i]["record"]["record"],body["data"][i]["achieved_game"]["game_name"],body["data"][i]["record"]["achieve_date"])
                        title="<"+str(year)+" "+str(gender_code_dict[gender_code])+" "+str(waterway_code_dict[waterway_code])+" "+str(distance_code_dict[distance_code])+" "+str(swimming_style_code_dict[swimming_style_code])+">"
                        body_for_notion = {
                            "parent": {
                                "database_id": databases_id
                            },
                            "properties": {
                                "Rank": {"title": [{"text": {"content": title}}]}
                            }
                        }
                        res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                        print("\n")
# Out:
# < 2008 Women LCM 400M IM >
# < 2008 Women LCM 200M IM >
# < 2008 Women LCM 200M Fly >
# < 2008 Women LCM 100M Fly >
# < 2008 Women LCM 50M Fly >
# < 2008 Women LCM 200M Br >
# < 2008 Women LCM 100M Br >
# < 2008 Women LCM 50M Br >
# < 2008 Women LCM 200M Ba >
# < 2008 Women LCM 100M Ba >
# < 2008 Women LCM 50M Ba >
# < 2008 Women LCM 1500M Fr >
# < 2008 Women LCM 800M Fr >
# < 2008 Women LCM 400M Fr >
# < 2008 Women LCM 200M Fr >
# < 2008 Women LCM 100M Fr >
# < 2008 Women LCM 50M Fr >
# < 2008 Men LCM 400M IM >
# < 2008 Men LCM 200M IM >
# < 2008 Men LCM 200M Fly >
# < 2008 Men LCM 100M Fly >
# < 2008 Men LCM 50M Fly >
# < 2008 Men LCM 200M Br >
# < 2008 Men LCM 100M Br >
# < 2008 Men LCM 50M Br >
# < 2008 Men LCM 200M Ba >
# < 2008 Men LCM 100M Ba >
# < 2008 Men LCM 50M Ba >
# < 2008 Men LCM 1500M Fr >
# < 2008 Men LCM 800M Fr >
# < 2008 Men LCM 400M Fr >
# < 2008 Men LCM 200M Fr >
# < 2008 Men LCM 100M Fr >
# < 2008 Men LCM 50M Fr >
# < 2009 Women LCM 400M IM >
# ...

# %%
from urllib.parse import urlencode
from urllib.request import urlopen, Request
import base64

headers = {
    "accept" :"application/json",
    "Content-Type" :"application/x-www-form-urlencoded"
}


waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}

swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
year=2017
waterway_code=1
gender_code=2
distance_code=3
swimming_style_code=1
firsturl="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page=1"
request= Request(firsturl, headers=headers)
with urlopen(request) as response:
    allpage=json.loads(response.read())["meta"]["last_page"]
allpage=1

for year in range(2020,2023):#<2020 Men LCM 200M Fly>でHTTPError: HTTP Error 429: Too Many Requestsが出た
    for gender_code in range(2,0,-1):
        if year==2020 and gender_code==2:
            continue
        for waterway_code in range(1,2):
            for swimming_style_code in range(5,0,-1):
                if year==2020 and gender_code==1 and swimming_style_code==5:
                    continue
                if swimming_style_code==5:
                    for distance_code in range(5,3,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                elif swimming_style_code==1:
                    for distance_code in range(7,1,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                else:
                    for distance_code in range(4,1,-1):
                        if year==2020 and gender_code==1 and swimming_style_code==4 and distance_code==4:
                            continue
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")

for year in range(2020,2023):##<2020 Men LCM 200M Fly>でHTTPError: HTTP Error 429: Too Many Requestsが出た
    for gender_code in range(2,0,-1):
        if year==2020 and gender_code==2:
            continue
        for waterway_code in range(1,2):
            for swimming_style_code in range(5,0,-1):
                if year==2020 and gender_code==1 and swimming_style_code==5:
                    continue
                if swimming_style_code==5:
                    for distance_code in range(5,3,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                            #{'ranking': 1, 'ranking_in_overall': 1, 'record': {'id': 19889392, 'is_relay_first': False, 'record': '1:55.04', 'achieve_date': '2018年02月17日(土)', 'is_new': False}, 'swimmers': {'swimmer_name': '池江璃花子', 'swimmer_code': '3479935', 'entry_group': {'code': '13560', 'name': 'ﾙﾈｻﾝｽ亀戸', 'short_name': 'ﾙﾈｻﾝｽ亀戸', 'member_group': {'code': 13, 'name': '東京'}}, 'school_class': {'code': 3, 'name': '高校', 'school_grades': [2]}}, 'achieved_game': {'game_name': '東京：KONAMI OPEN 2018', 'game_code': '1317644', 'division': {'code': 4, 'name': '決勝(A-決勝)'}, 'swimming_style_code': 1, 'distance_code': 4, 'gender_code': 2, 'race_division_code': 4, 'class_code': 4, 'heat': 1}, 'updated_at': '2021/04/03/00:33'}
                            for i in range(len(body["data"])-1,-1,-1):
                                body_for_notion = {
                                        "parent": {
                                            "database_id": databases_id
                                        },
                                        "properties": {
                                                "Rank": {"title": [{"text": {"content": str(body["data"][i]["ranking"])}}]},
                                                "Name": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["swimmer_name"]}}]},
                                                "EntryGroup": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["entry_group"]["name"]}}]},
                                                "Time": {"rich_text": [{"text": {"content": body["data"][i]["record"]["record"]}}]},
                                                "Game": {"rich_text": [{"text": {"content": body["data"][i]["achieved_game"]["game_name"]}}]},
                                                "Date": {"rich_text": [{"text": {"content": body["data"][i]["record"]["achieve_date"]}}]},
                                        }
                                }
                                res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                                print(body["data"][i]["ranking"],body["data"][i]["swimmers"]["swimmer_name"],body["data"][i]["swimmers"]["entry_group"]["name"],body["data"][i]["record"]["record"],body["data"][i]["achieved_game"]["game_name"],body["data"][i]["record"]["achieve_date"])
                        title="<"+str(year)+" "+str(gender_code_dict[gender_code])+" "+str(waterway_code_dict[waterway_code])+" "+str(distance_code_dict[distance_code])+" "+str(swimming_style_code_dict[swimming_style_code])+">"
                        body_for_notion = {
                            "parent": {
                                "database_id": databases_id
                            },
                            "properties": {
                                "Rank": {"title": [{"text": {"content": title}}]}
                            }
                        }
                        res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                        print("\n")
                elif swimming_style_code==1:
                    for distance_code in range(7,1,-1):
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                            #{'ranking': 1, 'ranking_in_overall': 1, 'record': {'id': 19889392, 'is_relay_first': False, 'record': '1:55.04', 'achieve_date': '2018年02月17日(土)', 'is_new': False}, 'swimmers': {'swimmer_name': '池江璃花子', 'swimmer_code': '3479935', 'entry_group': {'code': '13560', 'name': 'ﾙﾈｻﾝｽ亀戸', 'short_name': 'ﾙﾈｻﾝｽ亀戸', 'member_group': {'code': 13, 'name': '東京'}}, 'school_class': {'code': 3, 'name': '高校', 'school_grades': [2]}}, 'achieved_game': {'game_name': '東京：KONAMI OPEN 2018', 'game_code': '1317644', 'division': {'code': 4, 'name': '決勝(A-決勝)'}, 'swimming_style_code': 1, 'distance_code': 4, 'gender_code': 2, 'race_division_code': 4, 'class_code': 4, 'heat': 1}, 'updated_at': '2021/04/03/00:33'}
                            for i in range(len(body["data"])-1,-1,-1):
                                body_for_notion = {
                                        "parent": {
                                            "database_id": databases_id
                                        },
                                        "properties": {
                                                "Rank": {"title": [{"text": {"content": str(body["data"][i]["ranking"])}}]},
                                                "Name": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["swimmer_name"]}}]},
                                                "EntryGroup": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["entry_group"]["name"]}}]},
                                                "Time": {"rich_text": [{"text": {"content": body["data"][i]["record"]["record"]}}]},
                                                "Game": {"rich_text": [{"text": {"content": body["data"][i]["achieved_game"]["game_name"]}}]},
                                                "Date": {"rich_text": [{"text": {"content": body["data"][i]["record"]["achieve_date"]}}]},
                                        }
                                }
                                res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                                print(body["data"][i]["ranking"],body["data"][i]["swimmers"]["swimmer_name"],body["data"][i]["swimmers"]["entry_group"]["name"],body["data"][i]["record"]["record"],body["data"][i]["achieved_game"]["game_name"],body["data"][i]["record"]["achieve_date"])
                        title="<"+str(year)+" "+str(gender_code_dict[gender_code])+" "+str(waterway_code_dict[waterway_code])+" "+str(distance_code_dict[distance_code])+" "+str(swimming_style_code_dict[swimming_style_code])+">"
                        body_for_notion = {
                            "parent": {
                                "database_id": databases_id
                            },
                            "properties": {
                                "Rank": {"title": [{"text": {"content": title}}]}
                            }
                        }
                        res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                        print("\n")
                else:
                    for distance_code in range(4,1,-1):
                        if year==2020 and gender_code==1 and swimming_style_code==4 and distance_code==4:
                            continue
                        print("<",year,gender_code_dict[gender_code],waterway_code_dict[waterway_code],distance_code_dict[distance_code],swimming_style_code_dict[swimming_style_code],">")
                        for p in range(1,allpage+1):
                            url="https://result.swim.or.jp/api/v1/rankings/results?year="+str(year)+"&waterway_code="+str(waterway_code)+"&gender_code="+str(gender_code)+"&distance_code="+str(distance_code)+"&swimming_style_code="+str(swimming_style_code)+"&school_class_code=99&school_grade=99&page="+str(p)
                            request= Request(url, headers=headers)
                            with urlopen(request) as response:
                                body=json.loads(response.read())
                            #{'ranking': 1, 'ranking_in_overall': 1, 'record': {'id': 19889392, 'is_relay_first': False, 'record': '1:55.04', 'achieve_date': '2018年02月17日(土)', 'is_new': False}, 'swimmers': {'swimmer_name': '池江璃花子', 'swimmer_code': '3479935', 'entry_group': {'code': '13560', 'name': 'ﾙﾈｻﾝｽ亀戸', 'short_name': 'ﾙﾈｻﾝｽ亀戸', 'member_group': {'code': 13, 'name': '東京'}}, 'school_class': {'code': 3, 'name': '高校', 'school_grades': [2]}}, 'achieved_game': {'game_name': '東京：KONAMI OPEN 2018', 'game_code': '1317644', 'division': {'code': 4, 'name': '決勝(A-決勝)'}, 'swimming_style_code': 1, 'distance_code': 4, 'gender_code': 2, 'race_division_code': 4, 'class_code': 4, 'heat': 1}, 'updated_at': '2021/04/03/00:33'}
                            for i in range(len(body["data"])-1,-1,-1):
                                body_for_notion = {
                                        "parent": {
                                            "database_id": databases_id
                                        },
                                        "properties": {
                                                "Rank": {"title": [{"text": {"content": str(body["data"][i]["ranking"])}}]},
                                                "Name": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["swimmer_name"]}}]},
                                                "EntryGroup": {"rich_text": [{"text": {"content": body["data"][i]["swimmers"]["entry_group"]["name"]}}]},
                                                "Time": {"rich_text": [{"text": {"content": body["data"][i]["record"]["record"]}}]},
                                                "Game": {"rich_text": [{"text": {"content": body["data"][i]["achieved_game"]["game_name"]}}]},
                                                "Date": {"rich_text": [{"text": {"content": body["data"][i]["record"]["achieve_date"]}}]},
                                        }
                                }
                                res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                                print(body["data"][i]["ranking"],body["data"][i]["swimmers"]["swimmer_name"],body["data"][i]["swimmers"]["entry_group"]["name"],body["data"][i]["record"]["record"],body["data"][i]["achieved_game"]["game_name"],body["data"][i]["record"]["achieve_date"])
                        title="<"+str(year)+" "+str(gender_code_dict[gender_code])+" "+str(waterway_code_dict[waterway_code])+" "+str(distance_code_dict[distance_code])+" "+str(swimming_style_code_dict[swimming_style_code])+">"
                        body_for_notion = {
                            "parent": {
                                "database_id": databases_id
                            },
                            "properties": {
                                "Rank": {"title": [{"text": {"content": title}}]}
                            }
                        }
                        res = requests.request('POST', url=get_request_url('pages'), headers=headers_for_notion, data=json.dumps(body_for_notion))
                        print("\n")
# Out:
# < 2020 Men LCM 100M Fly >
# < 2020 Men LCM 50M Fly >
# < 2020 Men LCM 200M Br >
# < 2020 Men LCM 100M Br >
# < 2020 Men LCM 50M Br >
# < 2020 Men LCM 200M Ba >
# < 2020 Men LCM 100M Ba >
# < 2020 Men LCM 50M Ba >
# < 2020 Men LCM 1500M Fr >
# < 2020 Men LCM 800M Fr >
# < 2020 Men LCM 400M Fr >
# < 2020 Men LCM 200M Fr >
# < 2020 Men LCM 100M Fr >
# < 2020 Men LCM 50M Fr >
# < 2021 Women LCM 400M IM >
# < 2021 Women LCM 200M IM >
# < 2021 Women LCM 200M Fly >
# < 2021 Women LCM 100M Fly >
# < 2021 Women LCM 50M Fly >
# < 2021 Women LCM 200M Br >
# < 2021 Women LCM 100M Br >
# < 2021 Women LCM 50M Br >
# < 2021 Women LCM 200M Ba >
# < 2021 Women LCM 100M Ba >
# < 2021 Women LCM 50M Ba >
# < 2021 Women LCM 1500M Fr >
# < 2021 Women LCM 800M Fr >
# < 2021 Women LCM 400M Fr >
# < 2021 Women LCM 200M Fr >
# < 2021 Women LCM 100M Fr >
# < 2021 Women LCM 50M Fr >
# < 2021 Men LCM 400M IM >
# < 2021 Men LCM 200M IM >
# < 2021 Men LCM 200M Fly >
# < 2021 Men LCM 100M Fly >
# ...
